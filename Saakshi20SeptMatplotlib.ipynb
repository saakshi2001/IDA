# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x_axis=np.array([1,10])
y_axis=np.array([1,50])

# %%
plt.plot(x_axis,y_axis)

# %%
y_points=np.array([1,10,2,8,5])
plt.plot(y_points)

# %%
plt.plot(y_points,marker="*")

# %%
plt.plot(y_points,marker="o",linestyle="dotted")
plt.xlabel("Speed")
plt.ylabel("Velocity")
plt.title("Sample Chart")
# Out:
# Text(0.5, 1.0, 'Sample Chart')

# %%
month=np.array(['January', 'February', 'March', 'April', 'May'])
sales=np.array([2500, 3200, 2800, 4100, 3700])
plt.bar(month,sales)
plt.xlabel("Month")
plt.ylabel("Sales")
plt.title("Monthly Sales Data")
# Out:
# Text(0.5, 1.0, 'Monthly Sales Data')

# %%
plt.savefig("MonthlySales.png")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("sales_data.csv")

# %%
df.isnull().sum()
# Out:
# Date       0
# Product    0
# Sales      0
# dtype: int64

# %%
df.dtypes
# Out:
# Date       object
# Product    object
# Sales       int64
# dtype: object

# %%
#Total revenue for the entire dataset
total_revenue=np.sum(df['Sales'])
total_revenue
# Out:
# 53844

# %%
#total quantity sold for each product
df.groupby(['Product']).sum()
# Out:
# /tmp/ipykernel_2681/4087022635.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Product']).sum()
#            Sales
# Product
# Product A  21572
# Product B  20991
# Product C  11281

# %%
#Monthly Total Revenue
# Out:
# [4, 8]

# %%
#Monthly average revenue for each product
# Out:
# [1, 6, 7, 8, 5]
